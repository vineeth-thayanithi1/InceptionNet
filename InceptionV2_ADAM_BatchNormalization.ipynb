# %%
import tensorflow 
import tensorflow.keras
from keras.datasets import cifar100
from keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy as np
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten
from keras.activations import relu
from keras.metrics import Precision,Recall
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import SGD
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.models import Model
from datetime import datetime
import tensorboard
import keras

(x_train,y_train),(x_test,y_test)=cifar100.load_data()


es= EarlyStopping(monitor='val_loss', patience=3)
mc= ModelCheckpoint(filepath='InceptionV2_ADAM_BatchNormalization.h5', monitor='val_loss', save_best_only=True)

y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

mean = x_train.mean()
std= x_train.std()
x_train=(x_train-mean)/std

mean = x_test.mean()
std= x_test.std()
x_test=(x_test-mean)/std

def module_1(x):


  conv1_1= Conv2D(8, (1, 1), padding='same',activation='relu')(x)
  conv1_1=(BatchNormalization())(conv1_1)

  conv1_2= Conv2D(16, (3, 3), padding='same',activation='relu')(conv1_1)
  conv1_2=(BatchNormalization())(conv1_2)

  conv1_3= Conv2D(16, (3, 3), padding='same')(conv1_2)
  conv1_3=(BatchNormalization())(conv1_3)

  conv2_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv2_1=(BatchNormalization())(conv2_1)

  conv2_2= Conv2D(32, (3, 3), padding='same')(conv2_1)
  conv2_2=(BatchNormalization())(conv2_2)
  
  conv3_1= Conv2D(8, (1, 1), padding='same')(x)
  conv3_1=(BatchNormalization())(conv3_1)

  maxpool4_1= MaxPooling2D(pool_size=(3,3),strides=1,padding='same')(x)
  conv4_2= Conv2D(8, (1, 1), padding='same')(maxpool4_1)
  conv4_2=(BatchNormalization())(conv4_2)

  return keras.layers.concatenate([conv1_3,conv2_2,conv3_1,conv4_2],axis=3)

def module_2(x):


  conv1_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv1_1=(BatchNormalization())(conv1_1)

  conv1_2= Conv2D(32, (1, 3), padding='same',activation='relu')(conv1_1)
  conv1_2=(BatchNormalization())(conv1_2)

  conv1_3= Conv2D(32, (3, 1), padding='same',activation='relu')(conv1_2)
  conv1_3=(BatchNormalization())(conv1_3)

  conv1_4= Conv2D(32, (1, 3), padding='same',activation='relu')(conv1_3)
  conv1_4=(BatchNormalization())(conv1_4)

  conv1_5= Conv2D(32, (3, 1), padding='same')(conv1_4)
  conv1_5=(BatchNormalization())(conv1_5)

  conv2_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv2_1=(BatchNormalization())(conv2_1)

  conv2_2= Conv2D(48, (3, 1), padding='same',activation='relu')(conv2_1)
  conv2_2=(BatchNormalization())(conv2_2)

  conv2_3= Conv2D(48, (1, 3), padding='same')(conv2_2)
  conv2_3=(BatchNormalization())(conv2_3)
  
  conv3_1= Conv2D(16, (1, 1), padding='same')(x)
  conv3_1=(BatchNormalization())(conv3_1)

  maxpool4_1= MaxPooling2D(pool_size=(3,3),strides=1,padding='same')(x)
  conv4_2= Conv2D(32, (1, 1), padding='same')(maxpool4_1)
  conv4_2=(BatchNormalization())(conv4_2)

  return keras.layers.concatenate([conv1_5,conv2_3,conv3_1,conv4_2])


def module_3(x):


  conv1_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv1_1=(BatchNormalization())(conv1_1)

  conv1_2= Conv2D(32, (3, 3), padding='same',activation='relu')(conv1_1)
  conv1_2=(BatchNormalization())(conv1_2)

  conv1_4= Conv2D(32, (1, 3), padding='same')(conv1_2)
  conv1_4=(BatchNormalization())(conv1_4)

  conv1_5= Conv2D(64, (3, 1), padding='same')(conv1_2)
  conv1_5=(BatchNormalization())(conv1_5)

  conv2_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv2_1=(BatchNormalization())(conv2_1)

  conv2_2= Conv2D(64, (3, 1), padding='same')(conv2_1)
  conv2_2=(BatchNormalization())(conv2_2)

  conv2_3= Conv2D(64, (1, 3), padding='same')(conv2_1)
  conv2_3=(BatchNormalization())(conv2_3)
  
  conv3_1= Conv2D(16, (1, 1), padding='same')(x)
  conv3_1=(BatchNormalization())(conv3_1)

  maxpool4_1= MaxPooling2D(pool_size=(3,3),strides=1,padding='same')(x)
  conv4_2= Conv2D(16, (1, 1), padding='same')(maxpool4_1)
  conv4_2=(BatchNormalization())(conv4_2)

  return keras.layers.concatenate([conv1_4,conv1_5,conv2_2,conv2_3,conv3_1,conv4_2])

def Inception_Model(input_shape): 

  inputs=Input(shape=[32,32,3])

  conv_1 = Conv2D(32, (3, 3), padding='same',strides=2, input_shape=(32,32,3))(inputs)
  conv_1=(BatchNormalization())(conv_1)
  relu_1 = Activation(relu)(conv_1)

  inception1=module_1(relu_1)
  relu_2= Activation(relu)(inception1)

  inception2=module_1(relu_2)
  relu_3= Activation(relu)(inception2)

  max_pool=  MaxPooling2D(pool_size=(2,2),padding='same')(relu_3)

  inception3=module_2(max_pool)
  relu_4= Activation(relu)(inception3)

  inception4=module_2(relu_4)
  relu_5= Activation(relu)(inception4)

  inception5=module_2(relu_5)
  relu_6= Activation(relu)(inception5)

  max_pool2=  MaxPooling2D(pool_size=(2,2),padding='same')(relu_6)

  inception6=module_3(max_pool2)
  relu_5= Activation(relu)(inception6)

  max_pool_final=  x = MaxPooling2D(pool_size=(2,2))(relu_5)
  flat= Flatten()(max_pool_final)

  dense= Dense(100,activation='softmax')(flat)

  model= Model( inputs=inputs, outputs =dense)
  return model

logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

model = Inception_Model((32,32,3))

opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy',Precision(),Recall()])
history=model.fit(x=x_train,y=y_train,epochs=100, validation_data=(x_test,y_test), callbacks=[es,mc,tensorboard_callback])

from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
#    1/1563 [..............................] - ETA: 0s - loss: 5.9757 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#    2/1563 [..............................] - ETA: 2:54 - loss: 5.9417 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0411s vs `on_train_batch_end` time: 0.1844s). Check your callbacks.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 4.2539 - accuracy: 0.0737 - precision: 0.4035 - recall: 0.0032 - val_loss: 3.8092 - val_accuracy: 0.1329 - val_precision: 0.5475 - val_recall: 0.0167
# Epoch 2/100
# 1563/1563 [==============================] - 35s 23ms/step - loss: 3.6546 - accuracy: 0.1520 - precision: 0.6159 - recall: 0.0202 - val_loss: 3.4825 - val_accuracy: 0.1819 - val_precision: 0.5936 - val_recall: 0.0355
# Epoch 3/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 3.3830 - accuracy: 0.1941 - precision: 0.6590 - recall: 0.0411 - val_loss: 3.2939 - val_accuracy: 0.2145 - val_precision: 0.6586 - val_recall: 0.0546
# Epoch 4/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 3.1650 - accuracy: 0.2352 - precision: 0.6915 - recall: 0.0614 - val_loss: 3.1350 - val_accuracy: 0.2403 - val_precision: 0.6909 - val_recall: 0.0742
# Epoch 5/100
# 1563/1563 [==============================] - 35s 23ms/step - loss: 2.9996 - accuracy: 0.2651 - precision: 0.7110 - recall: 0.0828 - val_loss: 3.0164 - val_accuracy: 0.2666 - val_precision: 0.7056 - val_recall: 0.0882
# Epoch 6/100
# 1563/1563 [==============================] - 36s 23ms/step - loss: 2.8547 - accuracy: 0.2921 - precision: 0.7192 - recall: 0.0999 - val_loss: 2.9325 - val_accuracy: 0.2829 - val_precision: 0.6937 - val_recall: 0.1051
# Epoch 7/100
# 1563/1563 [==============================] - 37s 23ms/step - loss: 2.7322 - accuracy: 0.3137 - precision: 0.7330 - recall: 0.1199 - val_loss: 2.8330 - val_accuracy: 0.3003 - val_precision: 0.6937 - val_recall: 0.1189
# Epoch 8/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 2.6176 - accuracy: 0.3358 - precision: 0.7431 - recall: 0.1383 - val_loss: 2.7891 - val_accuracy: 0.3139 - val_precision: 0.6873 - val_recall: 0.1435
# Epoch 9/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 2.5164 - accuracy: 0.3583 - precision: 0.7469 - recall: 0.1559 - val_loss: 2.7594 - val_accuracy: 0.3178 - val_precision: 0.6599 - val_recall: 0.1560
# Epoch 10/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 2.4173 - accuracy: 0.3805 - precision: 0.7569 - recall: 0.1744 - val_loss: 2.6472 - val_accuracy: 0.3416 - val_precision: 0.6998 - val_recall: 0.1695
# Epoch 11/100
# 1563/1563 [==============================] - 36s 23ms/step - loss: 2.3284 - accuracy: 0.3977 - precision: 0.7681 - recall: 0.1933 - val_loss: 2.6051 - val_accuracy: 0.3437 - val_precision: 0.6836 - val_recall: 0.1785
# Epoch 12/100
# 1563/1563 [==============================] - 36s 23ms/step - loss: 2.2397 - accuracy: 0.4194 - precision: 0.7715 - recall: 0.2114 - val_loss: 2.5866 - val_accuracy: 0.3505 - val_precision: 0.6834 - val_recall: 0.1958
# Epoch 13/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 2.1671 - accuracy: 0.4337 - precision: 0.7747 - recall: 0.2296 - val_loss: 2.5351 - val_accuracy: 0.3620 - val_precision: 0.6951 - val_recall: 0.1977
# Epoch 14/100
# 1563/1563 [==============================] - 36s 23ms/step - loss: 2.0913 - accuracy: 0.4499 - precision: 0.7802 - recall: 0.2450 - val_loss: 2.5311 - val_accuracy: 0.3665 - val_precision: 0.6861 - val_recall: 0.2105
# Epoch 15/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 2.0281 - accuracy: 0.4653 - precision: 0.7826 - recall: 0.2615 - val_loss: 2.4965 - val_accuracy: 0.3768 - val_precision: 0.6727 - val_recall: 0.2220
# Epoch 16/100
# 1563/1563 [==============================] - 35s 23ms/step - loss: 1.9622 - accuracy: 0.4795 - precision: 0.7940 - recall: 0.2778 - val_loss: 2.5020 - val_accuracy: 0.3750 - val_precision: 0.6640 - val_recall: 0.2219
# Epoch 17/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 1.9008 - accuracy: 0.4945 - precision: 0.7969 - recall: 0.2923 - val_loss: 2.4479 - val_accuracy: 0.3842 - val_precision: 0.6641 - val_recall: 0.2380
# Epoch 18/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 1.8342 - accuracy: 0.5091 - precision: 0.8025 - recall: 0.3095 - val_loss: 2.4618 - val_accuracy: 0.3872 - val_precision: 0.6594 - val_recall: 0.2439
# Epoch 19/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 1.7832 - accuracy: 0.5232 - precision: 0.8048 - recall: 0.3234 - val_loss: 2.4728 - val_accuracy: 0.3811 - val_precision: 0.6543 - val_recall: 0.2417
# Epoch 20/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 1.7379 - accuracy: 0.5303 - precision: 0.8053 - recall: 0.3396 - val_loss: 2.4460 - val_accuracy: 0.3956 - val_precision: 0.6564 - val_recall: 0.2577
# Epoch 21/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 1.6770 - accuracy: 0.5490 - precision: 0.8134 - recall: 0.3525 - val_loss: 2.4927 - val_accuracy: 0.3900 - val_precision: 0.6217 - val_recall: 0.2644
# Epoch 22/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 1.6315 - accuracy: 0.5589 - precision: 0.8177 - recall: 0.3701 - val_loss: 2.4463 - val_accuracy: 0.4004 - val_precision: 0.6417 - val_recall: 0.2717
# Epoch 23/100
# 1563/1563 [==============================] - 35s 22ms/step - loss: 1.5825 - accuracy: 0.5701 - precision: 0.8218 - recall: 0.3828 - val_loss: 2.4811 - val_accuracy: 0.3977 - val_precision: 0.6297 - val_recall: 0.2733

# %%
import keras 

(x_train,y_train),(x_test,y_test)=cifar100.load_data()
y_test=to_categorical(y_test)

mean = x_test.mean()
std= x_test.std()
x_test=(x_test-mean)/std


best_model= keras.models.load_model('InceptionV2_ADAM_BatchNormalization.h5')
_, acc,precision,recall = best_model.evaluate(x_test, y_test)

print("Accuracy: "+str(acc*100)+"%")
print("Precision: "+str(precision*100)+"%")
print("Recall: "+str(recall*100)+"%")
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 2.4460 - accuracy: 0.3956 - precision: 0.6564 - recall: 0.2577
# Accuracy: 39.559999108314514%
# Precision: 65.639328956604%
# Recall: 25.769999623298645%
