# %%
import tensorflow 
import tensorflow.keras
from keras.datasets import cifar100
from keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy as np
from keras.layers import Conv2D, Dropout, MaxPooling2D,Dense,Flatten
from keras.activations import relu
from keras.metrics import Precision,Recall
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import SGD
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.models import Model
from datetime import datetime
import tensorboard
import keras

(x_train,y_train),(x_test,y_test)=cifar100.load_data()


es= EarlyStopping(monitor='val_loss', patience=3)
mc= ModelCheckpoint(filepath='InceptionV2_ADAM_Dropout.h5', monitor='val_loss', save_best_only=True)

y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

mean = x_train.mean()
std= x_train.std()
x_train=(x_train-mean)/std

mean = x_test.mean()
std= x_test.std()
x_test=(x_test-mean)/std

def module_1(x):


  conv1_1= Conv2D(8, (1, 1), padding='same',activation='relu')(x)
  conv1_1=(BatchNormalization())(conv1_1)

  conv1_2= Conv2D(16, (3, 3), padding='same',activation='relu')(conv1_1)
  conv1_2=(BatchNormalization())(conv1_2)
  
  conv1_3= Conv2D(16, (3, 3), padding='same')(conv1_2)
  conv1_3=(BatchNormalization())(conv1_3)

  conv2_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv2_1=(BatchNormalization())(conv2_1)

  conv2_2= Conv2D(32, (3, 3), padding='same')(conv2_1)
  conv2_2=(BatchNormalization())(conv2_2)

  conv3_1= Conv2D(8, (1, 1), padding='same')(x)
  conv3_1=(BatchNormalization())(conv3_1)

  maxpool4_1= MaxPooling2D(pool_size=(3,3),strides=1,padding='same')(x)
  conv4_2= Conv2D(8, (1, 1), padding='same')(maxpool4_1)
  
  conv4_2=(BatchNormalization())(conv4_2)
  
  return keras.layers.concatenate([conv1_3,conv2_2,conv3_1,conv4_2],axis=3)

def module_2(x):


  conv1_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv1_1=(BatchNormalization())(conv1_1)

  conv1_2= Conv2D(32, (1, 3), padding='same',activation='relu')(conv1_1)
  conv1_2=(BatchNormalization())(conv1_2)

  conv1_3= Conv2D(32, (3, 1), padding='same',activation='relu')(conv1_2)
  conv1_3=(BatchNormalization())(conv1_3)

  conv1_4= Conv2D(32, (1, 3), padding='same',activation='relu')(conv1_3)
  conv1_4=(BatchNormalization())(conv1_4)

  conv1_5= Conv2D(32, (3, 1), padding='same')(conv1_4)
  conv1_5=(BatchNormalization())(conv1_5)

  conv2_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv2_1=(BatchNormalization())(conv2_1)

  conv2_2= Conv2D(48, (3, 1), padding='same',activation='relu')(conv2_1)
  conv2_2=(BatchNormalization())(conv2_2)

  conv2_3= Conv2D(48, (1, 3), padding='same')(conv2_2)
  conv2_3=(BatchNormalization())(conv2_3)

  conv3_1= Conv2D(16, (1, 1), padding='same')(x)
  conv3_1=(BatchNormalization())(conv3_1)

  maxpool4_1= MaxPooling2D(pool_size=(3,3),strides=1,padding='same')(x)
  conv4_2= Conv2D(32, (1, 1), padding='same')(maxpool4_1)
  conv4_2=(BatchNormalization())(conv4_2)

  return keras.layers.concatenate([conv1_5,conv2_3,conv3_1,conv4_2])


def module_3(x):


  conv1_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv1_1=(BatchNormalization())(conv1_1)

  conv1_2= Conv2D(32, (3, 3), padding='same',activation='relu')(conv1_1)
  conv1_2=(BatchNormalization())(conv1_2)

  conv1_4= Conv2D(32, (1, 3), padding='same')(conv1_2)
  conv1_4=(BatchNormalization())(conv1_4)

  conv1_5= Conv2D(64, (3, 1), padding='same')(conv1_2)
  conv1_5=(BatchNormalization())(conv1_5)

  conv2_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv2_1=(BatchNormalization())(conv2_1)

  conv2_2= Conv2D(64, (3, 1), padding='same')(conv2_1)
  conv2_2=(BatchNormalization())(conv2_2)

  conv2_3= Conv2D(64, (1, 3), padding='same')(conv2_1)
  conv2_3=(BatchNormalization())(conv2_3)

  conv3_1= Conv2D(16, (1, 1), padding='same')(x)
  conv3_1=(BatchNormalization())(conv3_1)

  maxpool4_1= MaxPooling2D(pool_size=(3,3),strides=1,padding='same')(x)
  conv4_2= Conv2D(16, (1, 1), padding='same')(maxpool4_1)
  conv4_2=(BatchNormalization())(conv4_2)

  return keras.layers.concatenate([conv1_4,conv1_5,conv2_2,conv2_3,conv3_1,conv4_2])

def Inception_Model(input_shape): 

  inputs=Input(shape=[32,32,3])

  conv_1 = Conv2D(32, (3, 3), padding='same',strides=2, input_shape=(32,32,3))(inputs)
  conv_1=(BatchNormalization())(conv_1)

  relu_1 = Activation(relu)(conv_1)

  inception1=module_1(relu_1)
  relu_2= Activation(relu)(inception1)

  inception2=module_1(relu_2)
  inception2=(Dropout(0.1))(inception2)
  relu_3= Activation(relu)(inception2)

  max_pool=  MaxPooling2D(pool_size=(2,2),padding='same')(relu_3)

  inception3=module_2(max_pool)
  inception3=(Dropout(0.2))(inception3)
  relu_4= Activation(relu)(inception3)

  inception4=module_2(relu_4)
  inception4=(Dropout(0.1))(inception4)
  relu_5= Activation(relu)(inception4)

  inception5=module_2(relu_5)
  inception5=(Dropout(0.2))(inception5)
  relu_6= Activation(relu)(inception5)

  max_pool2=  MaxPooling2D(pool_size=(2,2),padding='same')(relu_6)

  inception6=module_3(max_pool2)
  relu_5= Activation(relu)(inception6)

  max_pool_final=  x = MaxPooling2D(pool_size=(2,2))(relu_5)
  flat= Flatten()(max_pool_final)

  dense= Dense(100,activation='softmax')(flat)

  model= Model( inputs=inputs, outputs =dense)
  return model

logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

model = Inception_Model((32,32,3))

model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy',Precision(),Recall()])
history=model.fit(x=x_train,y=y_train,epochs=100, validation_data=(x_test,y_test), callbacks=[es,mc,tensorboard_callback])

from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
#    2/1563 [..............................] - ETA: 7:12 - loss: 6.2957 - accuracy: 0.0000e+00 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0328s vs `on_train_batch_end` time: 0.5209s). Check your callbacks.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 3.9967 - accuracy: 0.1078 - precision_2: 0.4484 - recall_2: 0.0116 - val_loss: 3.6006 - val_accuracy: 0.1506 - val_precision_2: 0.6935 - val_recall_2: 0.0129
# Epoch 2/100
# 1563/1563 [==============================] - 38s 24ms/step - loss: 3.2990 - accuracy: 0.2041 - precision_2: 0.6461 - recall_2: 0.0435 - val_loss: 3.2409 - val_accuracy: 0.2177 - val_precision_2: 0.7563 - val_recall_2: 0.0388
# Epoch 3/100
# 1563/1563 [==============================] - 38s 24ms/step - loss: 2.9152 - accuracy: 0.2743 - precision_2: 0.6760 - recall_2: 0.0869 - val_loss: 2.9803 - val_accuracy: 0.2641 - val_precision_2: 0.7300 - val_recall_2: 0.0611
# Epoch 4/100
# 1563/1563 [==============================] - 38s 24ms/step - loss: 2.5981 - accuracy: 0.3353 - precision_2: 0.7059 - recall_2: 0.1378 - val_loss: 2.6965 - val_accuracy: 0.3223 - val_precision_2: 0.7394 - val_recall_2: 0.1078
# Epoch 5/100
# 1563/1563 [==============================] - 37s 23ms/step - loss: 2.3475 - accuracy: 0.3868 - precision_2: 0.7219 - recall_2: 0.1909 - val_loss: 2.5574 - val_accuracy: 0.3480 - val_precision_2: 0.7425 - val_recall_2: 0.1384
# Epoch 6/100
# 1563/1563 [==============================] - 37s 23ms/step - loss: 2.1644 - accuracy: 0.4286 - precision_2: 0.7401 - recall_2: 0.2353 - val_loss: 2.5364 - val_accuracy: 0.3452 - val_precision_2: 0.6219 - val_recall_2: 0.1640
# Epoch 7/100
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.9977 - accuracy: 0.4639 - precision_2: 0.7484 - recall_2: 0.2770 - val_loss: 2.5928 - val_accuracy: 0.3442 - val_precision_2: 0.6731 - val_recall_2: 0.1699
# Epoch 8/100
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.8820 - accuracy: 0.4895 - precision_2: 0.7559 - recall_2: 0.3118 - val_loss: 2.6820 - val_accuracy: 0.3368 - val_precision_2: 0.6519 - val_recall_2: 0.1766
# Epoch 9/100
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.7581 - accuracy: 0.5211 - precision_2: 0.7692 - recall_2: 0.3467 - val_loss: 2.4284 - val_accuracy: 0.3745 - val_precision_2: 0.6754 - val_recall_2: 0.2093
# Epoch 10/100
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.6602 - accuracy: 0.5410 - precision_2: 0.7808 - recall_2: 0.3774 - val_loss: 2.4355 - val_accuracy: 0.3765 - val_precision_2: 0.6706 - val_recall_2: 0.2142
# Epoch 11/100
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.5723 - accuracy: 0.5633 - precision_2: 0.7841 - recall_2: 0.4008 - val_loss: 2.4608 - val_accuracy: 0.3751 - val_precision_2: 0.6547 - val_recall_2: 0.2184
# Epoch 12/100
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.4977 - accuracy: 0.5789 - precision_2: 0.7884 - recall_2: 0.4251 - val_loss: 2.2267 - val_accuracy: 0.4171 - val_precision_2: 0.7057 - val_recall_2: 0.2582
# Epoch 13/100
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.4281 - accuracy: 0.5975 - precision_2: 0.7990 - recall_2: 0.4469 - val_loss: 2.4361 - val_accuracy: 0.3838 - val_precision_2: 0.6337 - val_recall_2: 0.2453
# Epoch 14/100
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.3552 - accuracy: 0.6152 - precision_2: 0.8029 - recall_2: 0.4720 - val_loss: 2.2551 - val_accuracy: 0.4197 - val_precision_2: 0.6829 - val_recall_2: 0.2647
# Epoch 15/100
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.2998 - accuracy: 0.6290 - precision_2: 0.8088 - recall_2: 0.4913 - val_loss: 2.3777 - val_accuracy: 0.3952 - val_precision_2: 0.6193 - val_recall_2: 0.2611

# %%
import keras 

(x_train,y_train),(x_test,y_test)=cifar100.load_data()
y_test=to_categorical(y_test)

mean = x_test.mean()
std= x_test.std()
x_test=(x_test-mean)/std


best_model= keras.models.load_model('InceptionV2_ADAM_Dropout.h5')
_, acc,precision,recall = best_model.evaluate(x_test, y_test)

print("Accuracy: "+str(acc*100)+"%")
print("Precision: "+str(precision*100)+"%")
print("Recall: "+str(recall*100)+"%")
# Out:
# 313/313 [==============================] - 2s 8ms/step - loss: 2.2267 - accuracy: 0.4171 - precision_2: 0.7057 - recall_2: 0.2582
# Accuracy: 41.71000123023987%
# Precision: 70.56573033332825%
# Recall: 25.81999897956848%
