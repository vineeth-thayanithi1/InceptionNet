# %%
import tensorflow 
import tensorflow.keras
from keras.datasets import cifar100
from keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy as np
from keras.layers import Conv2D, Dropout, MaxPooling2D,Dense,Flatten
from keras.activations import relu
from keras.metrics import Precision,Recall
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import SGD
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.models import Model
from datetime import datetime
import tensorboard
import keras

(x_train,y_train),(x_test,y_test)=cifar100.load_data()


es= EarlyStopping(monitor='val_loss', patience=3)
mc= ModelCheckpoint(filepath='InceptionV2_SGD_Dropout.h5', monitor='val_loss', save_best_only=True)

y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

mean = x_train.mean()
std= x_train.std()
x_train=(x_train-mean)/std

mean = x_test.mean()
std= x_test.std()
x_test=(x_test-mean)/std

def module_1(x):


  conv1_1= Conv2D(8, (1, 1), padding='same',activation='relu')(x)
  conv1_1=(BatchNormalization())(conv1_1)

  conv1_2= Conv2D(16, (3, 3), padding='same',activation='relu')(conv1_1)
  conv1_2=(BatchNormalization())(conv1_2)
  
  conv1_3= Conv2D(16, (3, 3), padding='same')(conv1_2)
  conv1_3=(BatchNormalization())(conv1_3)

  conv2_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv2_1=(BatchNormalization())(conv2_1)

  conv2_2= Conv2D(32, (3, 3), padding='same')(conv2_1)
  conv2_2=(BatchNormalization())(conv2_2)

  conv3_1= Conv2D(8, (1, 1), padding='same')(x)
  conv3_1=(BatchNormalization())(conv3_1)

  maxpool4_1= MaxPooling2D(pool_size=(3,3),strides=1,padding='same')(x)
  conv4_2= Conv2D(8, (1, 1), padding='same')(maxpool4_1)
  
  conv4_2=(BatchNormalization())(conv4_2)
  
  return keras.layers.concatenate([conv1_3,conv2_2,conv3_1,conv4_2],axis=3)

def module_2(x):


  conv1_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv1_1=(BatchNormalization())(conv1_1)

  conv1_2= Conv2D(32, (1, 3), padding='same',activation='relu')(conv1_1)
  conv1_2=(BatchNormalization())(conv1_2)

  conv1_3= Conv2D(32, (3, 1), padding='same',activation='relu')(conv1_2)
  conv1_3=(BatchNormalization())(conv1_3)

  conv1_4= Conv2D(32, (1, 3), padding='same',activation='relu')(conv1_3)
  conv1_4=(BatchNormalization())(conv1_4)

  conv1_5= Conv2D(32, (3, 1), padding='same')(conv1_4)
  conv1_5=(BatchNormalization())(conv1_5)

  conv2_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv2_1=(BatchNormalization())(conv2_1)

  conv2_2= Conv2D(48, (3, 1), padding='same',activation='relu')(conv2_1)
  conv2_2=(BatchNormalization())(conv2_2)

  conv2_3= Conv2D(48, (1, 3), padding='same')(conv2_2)
  conv2_3=(BatchNormalization())(conv2_3)

  conv3_1= Conv2D(16, (1, 1), padding='same')(x)
  conv3_1=(BatchNormalization())(conv3_1)

  maxpool4_1= MaxPooling2D(pool_size=(3,3),strides=1,padding='same')(x)
  conv4_2= Conv2D(32, (1, 1), padding='same')(maxpool4_1)
  conv4_2=(BatchNormalization())(conv4_2)

  return keras.layers.concatenate([conv1_5,conv2_3,conv3_1,conv4_2])


def module_3(x):


  conv1_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv1_1=(BatchNormalization())(conv1_1)

  conv1_2= Conv2D(32, (3, 3), padding='same',activation='relu')(conv1_1)
  conv1_2=(BatchNormalization())(conv1_2)

  conv1_4= Conv2D(32, (1, 3), padding='same')(conv1_2)
  conv1_4=(BatchNormalization())(conv1_4)

  conv1_5= Conv2D(64, (3, 1), padding='same')(conv1_2)
  conv1_5=(BatchNormalization())(conv1_5)

  conv2_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv2_1=(BatchNormalization())(conv2_1)

  conv2_2= Conv2D(64, (3, 1), padding='same')(conv2_1)
  conv2_2=(BatchNormalization())(conv2_2)

  conv2_3= Conv2D(64, (1, 3), padding='same')(conv2_1)
  conv2_3=(BatchNormalization())(conv2_3)

  conv3_1= Conv2D(16, (1, 1), padding='same')(x)
  conv3_1=(BatchNormalization())(conv3_1)

  maxpool4_1= MaxPooling2D(pool_size=(3,3),strides=1,padding='same')(x)
  conv4_2= Conv2D(16, (1, 1), padding='same')(maxpool4_1)
  conv4_2=(BatchNormalization())(conv4_2)

  return keras.layers.concatenate([conv1_4,conv1_5,conv2_2,conv2_3,conv3_1,conv4_2])

def Inception_Model(input_shape): 

  inputs=Input(shape=[32,32,3])

  conv_1 = Conv2D(32, (3, 3), padding='same',strides=2, input_shape=(32,32,3))(inputs)
  conv_1=(BatchNormalization())(conv_1)

  relu_1 = Activation(relu)(conv_1)

  inception1=module_1(relu_1)
  relu_2= Activation(relu)(inception1)

  inception2=module_1(relu_2)
  inception2=(Dropout(0.1))(inception2)
  relu_3= Activation(relu)(inception2)

  max_pool=  MaxPooling2D(pool_size=(2,2),padding='same')(relu_3)

  inception3=module_2(max_pool)
  inception3=(Dropout(0.2))(inception3)
  relu_4= Activation(relu)(inception3)

  inception4=module_2(relu_4)
  inception4=(Dropout(0.1))(inception4)
  relu_5= Activation(relu)(inception4)

  inception5=module_2(relu_5)
  inception5=(Dropout(0.2))(inception5)
  relu_6= Activation(relu)(inception5)

  max_pool2=  MaxPooling2D(pool_size=(2,2),padding='same')(relu_6)

  inception6=module_3(max_pool2)
  relu_5= Activation(relu)(inception6)

  max_pool_final=  x = MaxPooling2D(pool_size=(2,2))(relu_5)
  flat= Flatten()(max_pool_final)

  dense= Dense(100,activation='softmax')(flat)

  model= Model( inputs=inputs, outputs =dense)
  return model

logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

model = Inception_Model((32,32,3))

opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy',Precision(),Recall()])
history=model.fit(x=x_train,y=y_train,epochs=100, validation_data=(x_test,y_test), callbacks=[es,mc,tensorboard_callback])

from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
#    2/1563 [..............................] - ETA: 7:28 - loss: 5.9457 - accuracy: 0.0000e+00 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 2.4458 - accuracy: 0.3705 - precision_4: 0.7354 - recall_4: 0.1677 - val_loss: 2.9620 - val_accuracy: 0.2719 - val_precision_4: 0.6699 - val_recall_4: 0.0895
# Epoch 14/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.3800 - accuracy: 0.3875 - precision_4: 0.7429 - recall_4: 0.1830 - val_loss: 2.9492 - val_accuracy: 0.2757 - val_precision_4: 0.7065 - val_recall_4: 0.0905
# Epoch 15/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.3149 - accuracy: 0.3990 - precision_4: 0.7427 - recall_4: 0.1949 - val_loss: 2.8696 - val_accuracy: 0.2844 - val_precision_4: 0.6853 - val_recall_4: 0.0991
# Epoch 16/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 2.2611 - accuracy: 0.4110 - precision_4: 0.7484 - recall_4: 0.2104 - val_loss: 2.7864 - val_accuracy: 0.3051 - val_precision_4: 0.7065 - val_recall_4: 0.1071
# Epoch 17/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 2.1952 - accuracy: 0.4232 - precision_4: 0.7588 - recall_4: 0.2224 - val_loss: 2.7744 - val_accuracy: 0.3033 - val_precision_4: 0.7006 - val_recall_4: 0.1205
# Epoch 18/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.1530 - accuracy: 0.4344 - precision_4: 0.7530 - recall_4: 0.2318 - val_loss: 2.7785 - val_accuracy: 0.3091 - val_precision_4: 0.7061 - val_recall_4: 0.1163
# Epoch 19/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 2.0951 - accuracy: 0.4481 - precision_4: 0.7655 - recall_4: 0.2460 - val_loss: 2.7170 - val_accuracy: 0.3147 - val_precision_4: 0.6780 - val_recall_4: 0.1318
# Epoch 20/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 2.0404 - accuracy: 0.4580 - precision_4: 0.7673 - recall_4: 0.2605 - val_loss: 2.7540 - val_accuracy: 0.3048 - val_precision_4: 0.6570 - val_recall_4: 0.1245
# Epoch 21/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.0040 - accuracy: 0.4680 - precision_4: 0.7713 - recall_4: 0.2715 - val_loss: 2.7248 - val_accuracy: 0.3154 - val_precision_4: 0.6846 - val_recall_4: 0.1424
# Epoch 22/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9564 - accuracy: 0.4777 - precision_4: 0.7782 - recall_4: 0.2806 - val_loss: 2.7032 - val_accuracy: 0.3224 - val_precision_4: 0.6554 - val_recall_4: 0.1476
# Epoch 23/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 1.9236 - accuracy: 0.4856 - precision_4: 0.7789 - recall_4: 0.2913 - val_loss: 2.6965 - val_accuracy: 0.3198 - val_precision_4: 0.6399 - val_recall_4: 0.1516
# Epoch 24/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.8798 - accuracy: 0.4948 - precision_4: 0.7808 - recall_4: 0.3016 - val_loss: 2.5996 - val_accuracy: 0.3362 - val_precision_4: 0.6909 - val_recall_4: 0.1565
# Epoch 25/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.8358 - accuracy: 0.5053 - precision_4: 0.7887 - recall_4: 0.3147 - val_loss: 2.6131 - val_accuracy: 0.3399 - val_precision_4: 0.6855 - val_recall_4: 0.1731
# Epoch 26/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 1.8070 - accuracy: 0.5131 - precision_4: 0.7822 - recall_4: 0.3229 - val_loss: 2.5810 - val_accuracy: 0.3427 - val_precision_4: 0.6607 - val_recall_4: 0.1727
# Epoch 27/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 1.7712 - accuracy: 0.5182 - precision_4: 0.7912 - recall_4: 0.3331 - val_loss: 2.5854 - val_accuracy: 0.3438 - val_precision_4: 0.6831 - val_recall_4: 0.1735
# Epoch 28/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.7383 - accuracy: 0.5285 - precision_4: 0.7905 - recall_4: 0.3426 - val_loss: 2.5565 - val_accuracy: 0.3512 - val_precision_4: 0.6781 - val_recall_4: 0.1860
# Epoch 29/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 1.7040 - accuracy: 0.5352 - precision_4: 0.7904 - recall_4: 0.3509 - val_loss: 2.5153 - val_accuracy: 0.3597 - val_precision_4: 0.6937 - val_recall_4: 0.1902
# Epoch 30/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.6769 - accuracy: 0.5416 - precision_4: 0.7972 - recall_4: 0.3592 - val_loss: 2.5399 - val_accuracy: 0.3529 - val_precision_4: 0.6600 - val_recall_4: 0.1858
# Epoch 31/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 1.6448 - accuracy: 0.5486 - precision_4: 0.7987 - recall_4: 0.3695 - val_loss: 2.5023 - val_accuracy: 0.3661 - val_precision_4: 0.6865 - val_recall_4: 0.1973
# Epoch 32/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.6179 - accuracy: 0.5568 - precision_4: 0.7997 - recall_4: 0.3766 - val_loss: 2.5751 - val_accuracy: 0.3455 - val_precision_4: 0.6357 - val_recall_4: 0.1857
# Epoch 33/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.5897 - accuracy: 0.5628 - precision_4: 0.8026 - recall_4: 0.3868 - val_loss: 2.5161 - val_accuracy: 0.3640 - val_precision_4: 0.6803 - val_recall_4: 0.2064
# Epoch 34/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.5561 - accuracy: 0.5704 - precision_4: 0.8077 - recall_4: 0.3960 - val_loss: 2.5094 - val_accuracy: 0.3679 - val_precision_4: 0.6706 - val_recall_4: 0.2050

# %%
import keras 

(x_train,y_train),(x_test,y_test)=cifar100.load_data()
y_test=to_categorical(y_test)

mean = x_test.mean()
std= x_test.std()
x_test=(x_test-mean)/std


best_model= keras.models.load_model('InceptionV2_SGD_Dropout.h5')
_, acc,precision,recall = best_model.evaluate(x_test, y_test)

print("Accuracy: "+str(acc*100)+"%")
print("Precision: "+str(precision*100)+"%")
print("Recall: "+str(recall*100)+"%")
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 2.5023 - accuracy: 0.3661 - precision_4: 0.6865 - recall_4: 0.1973
# Accuracy: 36.6100013256073%
# Precision: 68.64996552467346%
# Recall: 19.73000019788742%

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')
