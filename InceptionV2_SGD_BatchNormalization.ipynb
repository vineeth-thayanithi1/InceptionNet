# %%
import tensorflow 
import tensorflow.keras
from keras.datasets import cifar100
from keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy as np
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten
from keras.activations import relu
from keras.metrics import Precision,Recall
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import SGD
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.models import Model
from datetime import datetime
import tensorboard
import keras

(x_train,y_train),(x_test,y_test)=cifar100.load_data()


es= EarlyStopping(monitor='val_loss', patience=3)
mc= ModelCheckpoint(filepath='InceptionV2_SGD_BatchNormalization.h5', monitor='val_loss', save_best_only=True)

y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

mean = x_train.mean()
std= x_train.std()
x_train=(x_train-mean)/std

mean = x_test.mean()
std= x_test.std()
x_test=(x_test-mean)/std

def module_1(x):


  conv1_1= Conv2D(8, (1, 1), padding='same',activation='relu')(x)
  conv1_1=(BatchNormalization())(conv1_1)

  conv1_2= Conv2D(16, (3, 3), padding='same',activation='relu')(conv1_1)
  conv1_2=(BatchNormalization())(conv1_2)

  conv1_3= Conv2D(16, (3, 3), padding='same')(conv1_2)
  conv1_3=(BatchNormalization())(conv1_3)

  conv2_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv2_1=(BatchNormalization())(conv2_1)

  conv2_2= Conv2D(32, (3, 3), padding='same')(conv2_1)
  conv2_2=(BatchNormalization())(conv2_2)
  
  conv3_1= Conv2D(8, (1, 1), padding='same')(x)
  conv3_1=(BatchNormalization())(conv3_1)

  maxpool4_1= MaxPooling2D(pool_size=(3,3),strides=1,padding='same')(x)
  conv4_2= Conv2D(8, (1, 1), padding='same')(maxpool4_1)
  conv4_2=(BatchNormalization())(conv4_2)

  return keras.layers.concatenate([conv1_3,conv2_2,conv3_1,conv4_2],axis=3)

def module_2(x):


  conv1_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv1_1=(BatchNormalization())(conv1_1)

  conv1_2= Conv2D(32, (1, 3), padding='same',activation='relu')(conv1_1)
  conv1_2=(BatchNormalization())(conv1_2)

  conv1_3= Conv2D(32, (3, 1), padding='same',activation='relu')(conv1_2)
  conv1_3=(BatchNormalization())(conv1_3)

  conv1_4= Conv2D(32, (1, 3), padding='same',activation='relu')(conv1_3)
  conv1_4=(BatchNormalization())(conv1_4)

  conv1_5= Conv2D(32, (3, 1), padding='same')(conv1_4)
  conv1_5=(BatchNormalization())(conv1_5)

  conv2_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv2_1=(BatchNormalization())(conv2_1)

  conv2_2= Conv2D(48, (3, 1), padding='same',activation='relu')(conv2_1)
  conv2_2=(BatchNormalization())(conv2_2)

  conv2_3= Conv2D(48, (1, 3), padding='same')(conv2_2)
  conv2_3=(BatchNormalization())(conv2_3)
  
  conv3_1= Conv2D(16, (1, 1), padding='same')(x)
  conv3_1=(BatchNormalization())(conv3_1)

  maxpool4_1= MaxPooling2D(pool_size=(3,3),strides=1,padding='same')(x)
  conv4_2= Conv2D(32, (1, 1), padding='same')(maxpool4_1)
  conv4_2=(BatchNormalization())(conv4_2)

  return keras.layers.concatenate([conv1_5,conv2_3,conv3_1,conv4_2])


def module_3(x):


  conv1_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv1_1=(BatchNormalization())(conv1_1)

  conv1_2= Conv2D(32, (3, 3), padding='same',activation='relu')(conv1_1)
  conv1_2=(BatchNormalization())(conv1_2)

  conv1_4= Conv2D(32, (1, 3), padding='same')(conv1_2)
  conv1_4=(BatchNormalization())(conv1_4)

  conv1_5= Conv2D(64, (3, 1), padding='same')(conv1_2)
  conv1_5=(BatchNormalization())(conv1_5)

  conv2_1= Conv2D(16, (1, 1), padding='same',activation='relu')(x)
  conv2_1=(BatchNormalization())(conv2_1)

  conv2_2= Conv2D(64, (3, 1), padding='same')(conv2_1)
  conv2_2=(BatchNormalization())(conv2_2)

  conv2_3= Conv2D(64, (1, 3), padding='same')(conv2_1)
  conv2_3=(BatchNormalization())(conv2_3)
  
  conv3_1= Conv2D(16, (1, 1), padding='same')(x)
  conv3_1=(BatchNormalization())(conv3_1)

  maxpool4_1= MaxPooling2D(pool_size=(3,3),strides=1,padding='same')(x)
  conv4_2= Conv2D(16, (1, 1), padding='same')(maxpool4_1)
  conv4_2=(BatchNormalization())(conv4_2)

  return keras.layers.concatenate([conv1_4,conv1_5,conv2_2,conv2_3,conv3_1,conv4_2])

def Inception_Model(input_shape): 

  inputs=Input(shape=[32,32,3])

  conv_1 = Conv2D(32, (3, 3), padding='same',strides=2, input_shape=(32,32,3))(inputs)
  conv_1=(BatchNormalization())(conv_1)
  relu_1 = Activation(relu)(conv_1)

  inception1=module_1(relu_1)
  relu_2= Activation(relu)(inception1)

  inception2=module_1(relu_2)
  relu_3= Activation(relu)(inception2)

  max_pool=  MaxPooling2D(pool_size=(2,2),padding='same')(relu_3)

  inception3=module_2(max_pool)
  relu_4= Activation(relu)(inception3)

  inception4=module_2(relu_4)
  relu_5= Activation(relu)(inception4)

  inception5=module_2(relu_5)
  relu_6= Activation(relu)(inception5)

  max_pool2=  MaxPooling2D(pool_size=(2,2),padding='same')(relu_6)

  inception6=module_3(max_pool2)
  relu_5= Activation(relu)(inception6)

  max_pool_final=  x = MaxPooling2D(pool_size=(2,2))(relu_5)
  flat= Flatten()(max_pool_final)
  
  dense= Dense(100,activation='softmax')(flat)

  model= Model( inputs=inputs, outputs =dense)
  return model

logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

model = Inception_Model((32,32,3))

opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy',Precision(),Recall()])
history=model.fit(x=x_train,y=y_train,epochs=100, validation_data=(x_test,y_test), callbacks=[es,mc,tensorboard_callback])

from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 11s 0us/step
# Epoch 1/100
#    1/1563 [..............................] - ETA: 0s - loss: 6.3111 - accuracy: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#    2/1563 [..............................] - ETA: 3:09 - loss: 5.7337 - accuracy: 0.0156 - precision: 0.0000e+00 - recall: 0.0000e+00  WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0513s vs `on_train_batch_end` time: 0.1934s). Check your callbacks.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 4.1978 - accuracy: 0.0767 - precision: 0.3890 - recall: 0.0037 - val_loss: 3.7530 - val_accuracy: 0.1294 - val_precision: 0.5961 - val_recall: 0.0121
# Epoch 2/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 3.6272 - accuracy: 0.1550 - precision: 0.6116 - recall: 0.0196 - val_loss: 3.4694 - val_accuracy: 0.1821 - val_precision: 0.6052 - val_recall: 0.0302
# Epoch 3/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 3.3547 - accuracy: 0.1992 - precision: 0.6561 - recall: 0.0397 - val_loss: 3.2451 - val_accuracy: 0.2254 - val_precision: 0.6728 - val_recall: 0.0582
# Epoch 4/100
# 1563/1563 [==============================] - 38s 25ms/step - loss: 3.1427 - accuracy: 0.2344 - precision: 0.6787 - recall: 0.0592 - val_loss: 3.0841 - val_accuracy: 0.2526 - val_precision: 0.6820 - val_recall: 0.0813
# Epoch 5/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.9738 - accuracy: 0.2670 - precision: 0.7040 - recall: 0.0808 - val_loss: 2.9794 - val_accuracy: 0.2699 - val_precision: 0.6874 - val_recall: 0.0884
# Epoch 6/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.8260 - accuracy: 0.2975 - precision: 0.7302 - recall: 0.1017 - val_loss: 2.8553 - val_accuracy: 0.2961 - val_precision: 0.7002 - val_recall: 0.1142
# Epoch 7/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.7047 - accuracy: 0.3214 - precision: 0.7330 - recall: 0.1233 - val_loss: 2.7722 - val_accuracy: 0.3097 - val_precision: 0.7106 - val_recall: 0.1282
# Epoch 8/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.5784 - accuracy: 0.3483 - precision: 0.7469 - recall: 0.1429 - val_loss: 2.6972 - val_accuracy: 0.3250 - val_precision: 0.7154 - val_recall: 0.1458
# Epoch 9/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.4822 - accuracy: 0.3670 - precision: 0.7505 - recall: 0.1628 - val_loss: 2.6465 - val_accuracy: 0.3351 - val_precision: 0.7075 - val_recall: 0.1531
# Epoch 10/100
# 1563/1563 [==============================] - 38s 25ms/step - loss: 2.3827 - accuracy: 0.3865 - precision: 0.7588 - recall: 0.1797 - val_loss: 2.5765 - val_accuracy: 0.3521 - val_precision: 0.7154 - val_recall: 0.1782
# Epoch 11/100
# 1563/1563 [==============================] - 38s 24ms/step - loss: 2.2949 - accuracy: 0.4051 - precision: 0.7630 - recall: 0.2014 - val_loss: 2.5713 - val_accuracy: 0.3524 - val_precision: 0.6953 - val_recall: 0.1860
# Epoch 12/100
# 1563/1563 [==============================] - 38s 24ms/step - loss: 2.2135 - accuracy: 0.4224 - precision: 0.7664 - recall: 0.2194 - val_loss: 2.5105 - val_accuracy: 0.3676 - val_precision: 0.7017 - val_recall: 0.1992
# Epoch 13/100
# 1563/1563 [==============================] - 38s 24ms/step - loss: 2.1324 - accuracy: 0.4392 - precision: 0.7773 - recall: 0.2370 - val_loss: 2.4789 - val_accuracy: 0.3703 - val_precision: 0.7079 - val_recall: 0.2133
# Epoch 14/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 2.0626 - accuracy: 0.4558 - precision: 0.7804 - recall: 0.2540 - val_loss: 2.4652 - val_accuracy: 0.3727 - val_precision: 0.6863 - val_recall: 0.2159
# Epoch 15/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.9899 - accuracy: 0.4738 - precision: 0.7873 - recall: 0.2708 - val_loss: 2.4448 - val_accuracy: 0.3834 - val_precision: 0.6887 - val_recall: 0.2290
# Epoch 16/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.9196 - accuracy: 0.4887 - precision: 0.7923 - recall: 0.2855 - val_loss: 2.4089 - val_accuracy: 0.3893 - val_precision: 0.6784 - val_recall: 0.2422
# Epoch 17/100
# 1563/1563 [==============================] - 38s 25ms/step - loss: 1.8701 - accuracy: 0.5021 - precision: 0.7934 - recall: 0.3010 - val_loss: 2.4255 - val_accuracy: 0.3871 - val_precision: 0.6695 - val_recall: 0.2437
# Epoch 18/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.8139 - accuracy: 0.5155 - precision: 0.8018 - recall: 0.3203 - val_loss: 2.3685 - val_accuracy: 0.3950 - val_precision: 0.6703 - val_recall: 0.2548
# Epoch 19/100
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.7582 - accuracy: 0.5256 - precision: 0.8053 - recall: 0.3336 - val_loss: 2.3771 - val_accuracy: 0.3994 - val_precision: 0.6537 - val_recall: 0.2647
# Epoch 20/100
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.6964 - accuracy: 0.5405 - precision: 0.8105 - recall: 0.3472 - val_loss: 2.4116 - val_accuracy: 0.3973 - val_precision: 0.6497 - val_recall: 0.2680
# Epoch 21/100
# 1563/1563 [==============================] - 38s 25ms/step - loss: 1.6462 - accuracy: 0.5524 - precision: 0.8143 - recall: 0.3639 - val_loss: 2.3646 - val_accuracy: 0.4048 - val_precision: 0.6603 - val_recall: 0.2751
# Epoch 22/100
# 1563/1563 [==============================] - 38s 25ms/step - loss: 1.5982 - accuracy: 0.5644 - precision: 0.8228 - recall: 0.3779 - val_loss: 2.3822 - val_accuracy: 0.4015 - val_precision: 0.6451 - val_recall: 0.2794
# Epoch 23/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.5552 - accuracy: 0.5765 - precision: 0.8250 - recall: 0.3908 - val_loss: 2.3886 - val_accuracy: 0.4064 - val_precision: 0.6525 - val_recall: 0.2862
# Epoch 24/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.5040 - accuracy: 0.5858 - precision: 0.8290 - recall: 0.4053 - val_loss: 2.3872 - val_accuracy: 0.4060 - val_precision: 0.6422 - val_recall: 0.2922

# %%
import keras 

(x_train,y_train),(x_test,y_test)=cifar100.load_data()
y_test=to_categorical(y_test)

mean = x_test.mean()
std= x_test.std()
x_test=(x_test-mean)/std


best_model= keras.models.load_model('InceptionV2_SGD_BatchNormalization.h5')
_, acc,precision,recall = best_model.evaluate(x_test, y_test)

print("Accuracy: "+str(acc*100)+"%")
print("Precision: "+str(precision*100)+"%")
print("Recall: "+str(recall*100)+"%")
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 2.3646 - accuracy: 0.4048 - precision: 0.6603 - recall: 0.2751
# Accuracy: 40.47999978065491%
# Precision: 66.03456735610962%
# Recall: 27.50999927520752%
